# %%
import pandas as pd
import pickle
import numpy as np
import re
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# %%
model = pickle.load(open('model.pkl','rb'))

# %%
def tokenize(text):
    tokens = word_tokenize(text)
    lemmatizer = WordNetLemmatizer()

    clean_tokens = []
    for tok in tokens:
        clean_tok = lemmatizer.lemmatize(tok).lower().strip()
        clean_tokens.append(clean_tok)
    # print(clean_tokens)
    return clean_tokens

# %%
df = pd.read_csv('final.csv')

# %%
x = df['Text']
y = df['Label']

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y)

# %%
vect = CountVectorizer(tokenizer=tokenize)
tfidf = TfidfTransformer()
clf = RandomForestClassifier()

    # train classifier
X_train_counts = vect.fit_transform(X_train)
X_train_tfidf = tfidf.fit_transform(X_train_counts)
clf.fit(X_train_tfidf, y_train)
# Out:
# C:\Users\ashish.kushaj\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# RandomForestClassifier()

# %%
X_train_counts = vect.fit_transform(X_train)
# Out:
# C:\Users\ashish.kushaj\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
X_train
# Out:
# 20573    thanks thank you for your answer to my questio...
# 6650     ((((((((((HUGS)))))))))) I love you tons and l...
# 2480                        Well thank you :] you are too!
# 22770       two bots one girl tcot p feminism sjw sjwlogic
# 12755    I nominate @BadEvan in #personal because he's ...
#                                ...
# 26766    thats it final straw were doing this you and m...
# 22041            really is it wintel this is windows intel
# 26936    dont you have a real job maybe you should read...
# 4742                                           im a girl:)
# 2187                                       synonym book :P
# Name: Text, Length: 20352, dtype: object

# %%
X_train_counts
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 304876 stored elements and shape (20352, 22878)>

# %%
X_train_tfidf = tfidf.fit_transform(X_train_counts)

# %%
clf.fit(X_train_tfidf, y_train)
# Out:
# RandomForestClassifier()

# %%
X_test_counts = vect.transform(X_test)
X_test_tfidf = tfidf.transform(X_test_counts)
y_test_pred = clf.predict(X_test_tfidf)

# %%
y_test_pred
# Out:
# array([0, 0, 1, ..., 1, 0, 0], dtype=int64)

# %%
y_test_np = np.array(y_test)

# %%
len(y_test) == len(y_test_pred)
# Out:
# True

# %%
count = 0

for i in range(len(y_test)):
    if y_test_np[i] == y_test_pred[i]:
        count+=1

probability = count/len(y_test) * 100

# %%
probability
# Out:
# 90.70007369196757

# %%
df = pd.read_csv('final_2.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                               Text  Label  \
# 0           0    :) Aww!! Yeahh she is my best friend * rapha...      0
# 1           1                                  :) hahah thanksss      0
# 2           2    :) hey thank you  that means alot. is this w...      0
# 3           3                                :) hey thankyou! :D      0
# 4           4    :) i lovwe you to  :) we will meet haha me j...      0
#
#    Source  Age                                        predictions  label
# 0     NaN  NaN  [[{'label': 'toxic', 'score': 0.00309044588357...      0
# 1     NaN  NaN  [[{'label': 'toxic', 'score': 0.00133112294133...      0
# 2     NaN  NaN  [[{'label': 'toxic', 'score': 0.00059224915457...      0
# 3     NaN  NaN  [[{'label': 'toxic', 'score': 0.00066509732278...      0
# 4     NaN  NaN  [[{'label': 'toxic', 'score': 0.04947510734200...      0

# %%
original = df['Label']

# %%
modified = df['label']

# %%
len(original)
# Out:
# 27137

# %%
len(modified)
# Out:
# 27137

# %%
count = 0
for i in range(len(original)):
    if original[i] != modified[i]:
        count+=1

# %%
count
# Out:
# 10751

# %%
(df['Label'] != df['label']).sum()
# Out:
# 10751

# %%
df['diff'] = df.apply(lambda row: 'different' if row['label'] != row['Label'] else 'same', axis=1)

# %%
df.to_csv('final_3.csv')

# %%
df2 = pd.read_csv('final_2.csv')

# %%
import ast

df2['predictions'] = df2['predictions'].apply(ast.literal_eval)

# %%
def classify_prediction(predictions):
    if isinstance(predictions, list) and len(predictions) > 0:
        for pred in predictions[0]:  # Access the first element
            if pred['score'] > 0.5:
                return 1
    return 0

# %%
df2['label1'] = df2['predictions'].apply(classify_prediction)

# %%
df2.to_csv('final_3.csv')

# %%
df2['diff'] = df2.apply(lambda row: 'different' if row['Label'] != row['label1'] else 'same', axis=1)

# %%
df2.head()
# Out:
#    Unnamed: 0                                               Text  Label  \
# 0           0    :) Aww!! Yeahh she is my best friend * rapha...      0
# 1           1                                  :) hahah thanksss      0
# 2           2    :) hey thank you  that means alot. is this w...      0
# 3           3                                :) hey thankyou! :D      0
# 4           4    :) i lovwe you to  :) we will meet haha me j...      0
#
#    Source  Age                                        predictions  label1
# 0     NaN  NaN  [[{'label': 'toxic', 'score': 0.00309044588357...       0
# 1     NaN  NaN  [[{'label': 'toxic', 'score': 0.00133112294133...       0
# 2     NaN  NaN  [[{'label': 'toxic', 'score': 0.00059224915457...       0
# 3     NaN  NaN  [[{'label': 'toxic', 'score': 0.00066509732278...       0
# 4     NaN  NaN  [[{'label': 'toxic', 'score': 0.04947510734200...       0

# %%
(df2['Label']!=df2['label1']).sum()
# Out:
# 7414
